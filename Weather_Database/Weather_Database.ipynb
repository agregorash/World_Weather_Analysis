# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests

# %%
from citipy import citipy

# %%
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | winslow
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | riyadh
# Processing Record 10 of Set 1 | sao filipe
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | mount gambier
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | yumen
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | kentau
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | kysyl-syr
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | maningrida
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | mecca
# Processing Record 29 of Set 1 | taylorville
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | harboore
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | zhigansk
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | novoderevyankovskaya
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | port macquarie
# Processing Record 1 of Set 2 | fernandopolis
# Processing Record 2 of Set 2 | mayumba
# Processing Record 3 of Set 2 | asfi
# Processing Record 4 of Set 2 | haines junction
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | yuzhno-kurilsk
# Processing Record 8 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | beringovskiy
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | yulara
# Processing Record 17 of Set 2 | lorengau
# Processing Record 18 of Set 2 | ulladulla
# Processing Record 19 of Set 2 | tabou
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | pemba
# Processing Record 23 of Set 2 | eydhafushi
# Processing Record 24 of Set 2 | brookhaven
# Processing Record 25 of Set 2 | hasaki
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | soyo
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | ambilobe
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | lima
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | vardo
# Processing Record 37 of Set 2 | boat of garten
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 2 | nueve de julio
# Processing Record 40 of Set 2 | buchanan
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | pangody
# Processing Record 43 of Set 2 | saint-pierre
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | gizo
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | te anau
# Processing Record 48 of Set 2 | bilma
# Processing Record 49 of Set 2 | wonthaggi
# Processing Record 50 of Set 2 | nanakuli
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | isangel
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 3 | port lincoln
# Processing Record 8 of Set 3 | saint-georges
# Processing Record 9 of Set 3 | porto belo
# Processing Record 10 of Set 3 | surt
# Processing Record 11 of Set 3 | sinegorye
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | nishihara
# Processing Record 17 of Set 3 | fergus falls
# Processing Record 18 of Set 3 | fort-shevchenko
# Processing Record 19 of Set 3 | deputatskiy
# Processing Record 20 of Set 3 | seoul
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | khatra
# Processing Record 23 of Set 3 | abu kamal
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | karratha
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | kudahuvadhoo
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | socorro
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | dikson
# Processing Record 35 of Set 3 | nirmal
# Processing Record 36 of Set 3 | huarmey
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | mossendjo
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | santa cruz del norte
# Processing Record 42 of Set 3 | yorosso
# Processing Record 43 of Set 3 | tofte
# Processing Record 44 of Set 3 | bud
# Processing Record 45 of Set 3 | flin flon
# Processing Record 46 of Set 3 | bol
# Processing Record 47 of Set 3 | paoua
# Processing Record 48 of Set 3 | poum
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | mandurah
# Processing Record 1 of Set 4 | tuatapere
# Processing Record 2 of Set 4 | itoman
# Processing Record 3 of Set 4 | atherton
# Processing Record 4 of Set 4 | port hardy
# Processing Record 5 of Set 4 | avanigadda
# Processing Record 6 of Set 4 | sangar
# Processing Record 7 of Set 4 | stekolnyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | constantine
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | nome
# Processing Record 11 of Set 4 | challans
# Processing Record 12 of Set 4 | minab
# Processing Record 13 of Set 4 | sokoto
# Processing Record 14 of Set 4 | gazojak
# Processing Record 15 of Set 4 | pokrovsk
# Processing Record 16 of Set 4 | provost
# Processing Record 17 of Set 4 | juneau
# Processing Record 18 of Set 4 | pitsunda
# Processing Record 19 of Set 4 | fare
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | necochea
# Processing Record 24 of Set 4 | aksarka
# Processing Record 25 of Set 4 | saint-paul
# Processing Record 26 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 4 | lac du bonnet
# Processing Record 28 of Set 4 | jacareacanga
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | tiradentes
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | kirakira
# Processing Record 34 of Set 4 | bauta
# Processing Record 35 of Set 4 | liepaja
# Processing Record 36 of Set 4 | bolobo
# Processing Record 37 of Set 4 | christchurch
# Processing Record 38 of Set 4 | clearlake
# Processing Record 39 of Set 4 | domazlice
# Processing Record 40 of Set 4 | yatou
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | katsuura
# Processing Record 43 of Set 4 | zwedru
# Processing Record 44 of Set 4 | butaritari
# Processing Record 45 of Set 4 | mareeba
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | nouadhibou
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | moron
# Processing Record 50 of Set 4 | ukiah
# Processing Record 1 of Set 5 | copiapo
# Processing Record 2 of Set 5 | sokoni
# Processing Record 3 of Set 5 | ambunti
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | erzin
# Processing Record 7 of Set 5 | zavet
# Processing Record 8 of Set 5 | banjar
# Processing Record 9 of Set 5 | dawlatabad
# Processing Record 10 of Set 5 | panzhihua
# Processing Record 11 of Set 5 | comodoro rivadavia
# Processing Record 12 of Set 5 | yangambi
# Processing Record 13 of Set 5 | brainerd
# Processing Record 14 of Set 5 | kapaa
# Processing Record 15 of Set 5 | golaghat
# Processing Record 16 of Set 5 | taltal
# Processing Record 17 of Set 5 | matamoros
# Processing Record 18 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 5 | mehamn
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | marsh harbour
# Processing Record 22 of Set 5 | virar
# Processing Record 23 of Set 5 | brae
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | cherskiy
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | kozhva
# Processing Record 28 of Set 5 | bathsheba
# Processing Record 29 of Set 5 | praya
# Processing Record 30 of Set 5 | energeticheskiy
# Processing Record 31 of Set 5 | jiuquan
# Processing Record 32 of Set 5 | mattru
# Processing Record 33 of Set 5 | urucara
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | lamu
# Processing Record 37 of Set 5 | santiago
# Processing Record 38 of Set 5 | alice springs
# Processing Record 39 of Set 5 | ondangwa
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | ghansor
# Processing Record 42 of Set 5 | quatre cocos
# Processing Record 43 of Set 5 | beni suef
# Processing Record 44 of Set 5 | raga
# Processing Record 45 of Set 5 | arraial do cabo
# Processing Record 46 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | ca mau
# Processing Record 49 of Set 5 | liverpool
# Processing Record 50 of Set 5 | hamilton
# Processing Record 1 of Set 6 | camacupa
# Processing Record 2 of Set 6 | anadyr
# Processing Record 3 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 6 | dharchula
# Processing Record 5 of Set 6 | sola
# Processing Record 6 of Set 6 | naze
# Processing Record 7 of Set 6 | starodzhereliyevskaya
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | gorom-gorom
# Processing Record 10 of Set 6 | abu dhabi
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | sant feliu de guixols
# Processing Record 13 of Set 6 | dong hoi
# Processing Record 14 of Set 6 | medowie
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | naryan-mar
# Processing Record 17 of Set 6 | moosomin
# Processing Record 18 of Set 6 | west wendover
# Processing Record 19 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 21 of Set 6 | bonfim
# Processing Record 22 of Set 6 | palana
# Processing Record 23 of Set 6 | cabra
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | albert lea
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | belyy yar
# Processing Record 28 of Set 6 | puerto el triunfo
# Processing Record 29 of Set 6 | sambava
# Processing Record 30 of Set 6 | orange cove
# Processing Record 31 of Set 6 | bosobolo
# Processing Record 32 of Set 6 | luba
# Processing Record 33 of Set 6 | birin
# Processing Record 34 of Set 6 | tavda
# Processing Record 35 of Set 6 | san jose
# Processing Record 36 of Set 6 | simao
# Processing Record 37 of Set 6 | panguna
# Processing Record 38 of Set 6 | dingle
# Processing Record 39 of Set 6 | karla
# Processing Record 40 of Set 6 | chapais
# Processing Record 41 of Set 6 | havre-saint-pierre
# Processing Record 42 of Set 6 | launceston
# Processing Record 43 of Set 6 | swanzey
# Processing Record 44 of Set 6 | troy
# Processing Record 45 of Set 6 | barra do corda
# Processing Record 46 of Set 6 | nautanwa
# Processing Record 47 of Set 6 | bonavista
# Processing Record 48 of Set 6 | northfield
# Processing Record 49 of Set 6 | soke
# Processing Record 50 of Set 6 | madimba
# Processing Record 1 of Set 7 | caconda
# Processing Record 2 of Set 7 | pitimbu
# Processing Record 3 of Set 7 | marovoay
# Processing Record 4 of Set 7 | spearfish
# Processing Record 5 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 7 | broome
# Processing Record 7 of Set 7 | malanville
# Processing Record 8 of Set 7 | honningsvag
# Processing Record 9 of Set 7 | bairiki
# Processing Record 10 of Set 7 | tilichiki
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | bata
# Processing Record 13 of Set 7 | warrnambool
# Processing Record 14 of Set 7 | bati
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | tasiilaq
# Processing Record 20 of Set 7 | envira
# Processing Record 21 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 7 | williams lake
# Processing Record 24 of Set 7 | la ronge
# Processing Record 25 of Set 7 | tomatlan
# Processing Record 26 of Set 7 | sandavagur
# City not found. Skipping...
# Processing Record 27 of Set 7 | bodden town
# Processing Record 28 of Set 7 | nemuro
# Processing Record 29 of Set 7 | porto novo
# Processing Record 30 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 7 | ankang
# Processing Record 32 of Set 7 | ordzhonikidze
# Processing Record 33 of Set 7 | palu
# Processing Record 34 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | vredendal
# Processing Record 36 of Set 7 | pacific grove
# Processing Record 37 of Set 7 | meybod
# Processing Record 38 of Set 7 | vanavara
# Processing Record 39 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 7 | qaqortoq
# Processing Record 41 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 7 | yibin
# Processing Record 43 of Set 7 | padang
# Processing Record 44 of Set 7 | ternate
# Processing Record 45 of Set 7 | port hedland
# Processing Record 46 of Set 7 | palauig
# Processing Record 47 of Set 7 | coquimbo
# Processing Record 48 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 7 | beloha
# Processing Record 50 of Set 7 | jibuti
# Processing Record 1 of Set 8 | zlitan
# Processing Record 2 of Set 8 | samatau
# City not found. Skipping...
# Processing Record 3 of Set 8 | belmonte
# Processing Record 4 of Set 8 | shache
# Processing Record 5 of Set 8 | andujar
# Processing Record 6 of Set 8 | agadez
# Processing Record 7 of Set 8 | tual
# Processing Record 8 of Set 8 | tawau
# Processing Record 9 of Set 8 | tommot
# Processing Record 10 of Set 8 | koutsouras
# Processing Record 11 of Set 8 | arman
# Processing Record 12 of Set 8 | matara
# Processing Record 13 of Set 8 | erenhot
# Processing Record 14 of Set 8 | lasa
# Processing Record 15 of Set 8 | gedo
# Processing Record 16 of Set 8 | esterhazy
# Processing Record 17 of Set 8 | leshukonskoye
# Processing Record 18 of Set 8 | tonantins
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | tezu
# Processing Record 21 of Set 8 | egvekinot
# Processing Record 22 of Set 8 | gejiu
# Processing Record 23 of Set 8 | zeya
# Processing Record 24 of Set 8 | shingu
# Processing Record 25 of Set 8 | sikonge
# Processing Record 26 of Set 8 | ponta do sol
# Processing Record 27 of Set 8 | outjo
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | chumikan
# Processing Record 30 of Set 8 | sungaipenuh
# Processing Record 31 of Set 8 | tulum
# Processing Record 32 of Set 8 | doksy
# Processing Record 33 of Set 8 | caucaia
# Processing Record 34 of Set 8 | khandyga
# Processing Record 35 of Set 8 | indianola
# Processing Record 36 of Set 8 | broken hill
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | lerwick
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | bada
# Processing Record 41 of Set 8 | mizan teferi
# Processing Record 42 of Set 8 | birjand
# Processing Record 43 of Set 8 | qingdao
# Processing Record 44 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 45 of Set 8 | turinsk
# Processing Record 46 of Set 8 | beian
# Processing Record 47 of Set 8 | okato
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 8 | jiayuguan
# Processing Record 1 of Set 9 | manicore
# Processing Record 2 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 3 of Set 9 | jeremie
# Processing Record 4 of Set 9 | camacha
# Processing Record 5 of Set 9 | liwale
# Processing Record 6 of Set 9 | urumqi
# Processing Record 7 of Set 9 | taoudenni
# Processing Record 8 of Set 9 | curup
# Processing Record 9 of Set 9 | vao
# Processing Record 10 of Set 9 | houma
# Processing Record 11 of Set 9 | shenjiamen
# Processing Record 12 of Set 9 | bethel
# Processing Record 13 of Set 9 | melilla
# Processing Record 14 of Set 9 | santa rosa
# Processing Record 15 of Set 9 | thinadhoo
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | tchibanga
# Processing Record 18 of Set 9 | sorland
# Processing Record 19 of Set 9 | hare bay
# Processing Record 20 of Set 9 | ourem
# Processing Record 21 of Set 9 | el tigre
# Processing Record 22 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 9 | kamyaran
# Processing Record 24 of Set 9 | guymon
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | lavrentiya
# Processing Record 28 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 9 | olafsvik
# Processing Record 30 of Set 9 | pelhrimov
# Processing Record 31 of Set 9 | chicama
# Processing Record 32 of Set 9 | tucumcari
# Processing Record 33 of Set 9 | noumea
# Processing Record 34 of Set 9 | antibes
# Processing Record 35 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 9 | maldonado
# Processing Record 37 of Set 9 | palaiokipos
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | aykhal
# Processing Record 41 of Set 9 | vila velha
# Processing Record 42 of Set 9 | gillette
# Processing Record 43 of Set 9 | santa ana
# Processing Record 44 of Set 9 | sandwick
# Processing Record 45 of Set 9 | morondava
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | teacapan
# Processing Record 48 of Set 9 | mersin
# Processing Record 49 of Set 9 | ostrow mazowiecka
# Processing Record 50 of Set 9 | tadine
# Processing Record 1 of Set 10 | axim
# Processing Record 2 of Set 10 | high level
# Processing Record 3 of Set 10 | berkovica
# Processing Record 4 of Set 10 | lusambo
# Processing Record 5 of Set 10 | wattegama
# Processing Record 6 of Set 10 | saint-augustin
# Processing Record 7 of Set 10 | parana
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | corrales
# Processing Record 10 of Set 10 | atasu
# Processing Record 11 of Set 10 | swidnik
# Processing Record 12 of Set 10 | noyabrsk
# Processing Record 13 of Set 10 | bizhbulyak
# Processing Record 14 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 10 | pyay
# Processing Record 16 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 10 | orebro
# Processing Record 18 of Set 10 | kununurra
# Processing Record 19 of Set 10 | namibe
# Processing Record 20 of Set 10 | santa cruz del sur
# Processing Record 21 of Set 10 | bubaque
# Processing Record 22 of Set 10 | laguna
# Processing Record 23 of Set 10 | taber
# Processing Record 24 of Set 10 | bystryy istok
# Processing Record 25 of Set 10 | waipawa
# Processing Record 26 of Set 10 | baker city
# Processing Record 27 of Set 10 | rawlins
# Processing Record 28 of Set 10 | flinders
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | jieshi
# Processing Record 31 of Set 10 | colac
# Processing Record 32 of Set 10 | petropavlovka
# Processing Record 33 of Set 10 | maragogi
# Processing Record 34 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 10 | iberia
# Processing Record 36 of Set 10 | kalengwa
# Processing Record 37 of Set 10 | umm kaddadah
# Processing Record 38 of Set 10 | kiama
# Processing Record 39 of Set 10 | saravan
# Processing Record 40 of Set 10 | san quintin
# Processing Record 41 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 44 of Set 10 | jalalpur
# Processing Record 45 of Set 10 | shelburne
# Processing Record 46 of Set 10 | micheweni
# Processing Record 47 of Set 10 | sungairaya
# Processing Record 48 of Set 10 | san cristobal
# Processing Record 49 of Set 10 | bentiu
# Processing Record 50 of Set 10 | the valley
# Processing Record 1 of Set 11 | marzuq
# Processing Record 2 of Set 11 | phalombe
# Processing Record 3 of Set 11 | wamba
# Processing Record 4 of Set 11 | carrboro
# Processing Record 5 of Set 11 | santa luzia
# Processing Record 6 of Set 11 | sao francisco
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | namatanai
# Processing Record 9 of Set 11 | prince rupert
# Processing Record 10 of Set 11 | oranjemund
# Processing Record 11 of Set 11 | kahului
# Processing Record 12 of Set 11 | acapulco
# Processing Record 13 of Set 11 | pangnirtung
# Processing Record 14 of Set 11 | shoranur
# Processing Record 15 of Set 11 | chiredzi
# Processing Record 16 of Set 11 | gobabis
# Processing Record 17 of Set 11 | bereda
# Processing Record 18 of Set 11 | coulihaut
# City not found. Skipping...
# Processing Record 19 of Set 11 | beisfjord
# Processing Record 20 of Set 11 | coahuayana
# Processing Record 21 of Set 11 | olinda
# Processing Record 22 of Set 11 | abnub
# Processing Record 23 of Set 11 | waingapu
# Processing Record 24 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 11 | rocha
# Processing Record 26 of Set 11 | wagar
# Processing Record 27 of Set 11 | tecpan
# Processing Record 28 of Set 11 | russell
# Processing Record 29 of Set 11 | jiaohe
# Processing Record 30 of Set 11 | port hawkesbury
# Processing Record 31 of Set 11 | okhotsk
# Processing Record 32 of Set 11 | pampa
# Processing Record 33 of Set 11 | rajpipla
# Processing Record 34 of Set 11 | cocobeach
# Processing Record 35 of Set 11 | henties bay
# Processing Record 36 of Set 11 | coruripe
# Processing Record 37 of Set 11 | inta
# Processing Record 38 of Set 11 | alexandria
# Processing Record 39 of Set 11 | fuxin
# Processing Record 40 of Set 11 | ponta delgada
# Processing Record 41 of Set 11 | celestun
# Processing Record 42 of Set 11 | izumo
# Processing Record 43 of Set 11 | nagaur
# Processing Record 44 of Set 11 | north platte
# Processing Record 45 of Set 11 | gamba
# Processing Record 46 of Set 11 | kerouane
# Processing Record 47 of Set 11 | havelock
# Processing Record 48 of Set 11 | kralendijk
# Processing Record 49 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 11 | lae
# Processing Record 1 of Set 12 | gargzdai
# Processing Record 2 of Set 12 | ahipara
# Processing Record 3 of Set 12 | airai
# Processing Record 4 of Set 12 | mongoumba
# Processing Record 5 of Set 12 | villa rica
# Processing Record 6 of Set 12 | yangjiang
# Processing Record 7 of Set 12 | nijar
# Processing Record 8 of Set 12 | guerrero negro
# Processing Record 9 of Set 12 | caravelas
# Processing Record 10 of Set 12 | merauke
# Processing Record 11 of Set 12 | soe
# Processing Record 12 of Set 12 | chirongui
# Processing Record 13 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 12 | karimpur
# Processing Record 15 of Set 12 | puerto varas
# Processing Record 16 of Set 12 | pauini
# Processing Record 17 of Set 12 | cullman
# Processing Record 18 of Set 12 | totton
# Processing Record 19 of Set 12 | khorixas
# Processing Record 20 of Set 12 | svetlogorsk
# Processing Record 21 of Set 12 | salisbury
# Processing Record 22 of Set 12 | krasnyy chikoy
# Processing Record 23 of Set 12 | tarauaca
# Processing Record 24 of Set 12 | nushki
# Processing Record 25 of Set 12 | kimbe
# Processing Record 26 of Set 12 | asau
# Processing Record 27 of Set 12 | fortuna
# Processing Record 28 of Set 12 | mahon
# Processing Record 29 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 12 | nabire
# Processing Record 31 of Set 12 | cururupu
# Processing Record 32 of Set 12 | bangassou
# Processing Record 33 of Set 12 | katobu
# Processing Record 34 of Set 12 | ous
# Processing Record 35 of Set 12 | roald
# Processing Record 36 of Set 12 | black diamond
# Processing Record 37 of Set 12 | lazaro cardenas
# Processing Record 38 of Set 12 | lagunas
# Processing Record 39 of Set 12 | sobolevo
# Processing Record 40 of Set 12 | ranong
# Processing Record 41 of Set 12 | adilcevaz
# Processing Record 42 of Set 12 | strezhevoy
# Processing Record 43 of Set 12 | nuuk
# Processing Record 44 of Set 12 | chandler
# Processing Record 45 of Set 12 | milicz
# Processing Record 46 of Set 12 | acari
# Processing Record 47 of Set 12 | la asuncion
# Processing Record 48 of Set 12 | rorvik
# Processing Record 49 of Set 12 | ati
# Processing Record 50 of Set 12 | genhe
# Processing Record 1 of Set 13 | almonte
# Processing Record 2 of Set 13 | visby
# Processing Record 3 of Set 13 | mezen
# Processing Record 4 of Set 13 | aklavik
# Processing Record 5 of Set 13 | mitsamiouli
# Processing Record 6 of Set 13 | auki
# Processing Record 7 of Set 13 | pombas
# Processing Record 8 of Set 13 | tuy hoa
# Processing Record 9 of Set 13 | neepawa
# Processing Record 10 of Set 13 | krasnoselkup
# Processing Record 11 of Set 13 | port blair
# Processing Record 12 of Set 13 | champerico
# Processing Record 13 of Set 13 | gairo
# Processing Record 14 of Set 13 | kormilovka
# Processing Record 15 of Set 13 | manokwari
# Processing Record 16 of Set 13 | bestobe
# Processing Record 17 of Set 13 | cabo san lucas
# Processing Record 18 of Set 13 | chengde
# Processing Record 19 of Set 13 | oum hadjer
# Processing Record 20 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 21 of Set 13 | banda aceh
# Processing Record 22 of Set 13 | san andres
# Processing Record 23 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 24 of Set 13 | ruidoso
# Processing Record 25 of Set 13 | le mans
# Processing Record 26 of Set 13 | kangaatsiaq
# Processing Record 27 of Set 13 | erdenet
# Processing Record 28 of Set 13 | morada nova
# Processing Record 29 of Set 13 | nadvoitsy
# Processing Record 30 of Set 13 | changji
# Processing Record 31 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 32 of Set 13 | campana
# Processing Record 33 of Set 13 | iwaki
# Processing Record 34 of Set 13 | beruwala
# Processing Record 35 of Set 13 | esmeraldas
# Processing Record 36 of Set 13 | haldensleben
# Processing Record 37 of Set 13 | kutum
# Processing Record 38 of Set 13 | tiarei
# Processing Record 39 of Set 13 | bontang
# Processing Record 40 of Set 13 | luwuk
# Processing Record 41 of Set 13 | aktau
# Processing Record 42 of Set 13 | burgeo
# Processing Record 43 of Set 13 | mlonggo
# Processing Record 44 of Set 13 | north branch
# Processing Record 45 of Set 13 | savannah bight
# Processing Record 46 of Set 13 | east wenatchee bench
# Processing Record 47 of Set 13 | san pedro
# Processing Record 48 of Set 13 | dakar
# Processing Record 49 of Set 13 | praxedis guerrero
# Processing Record 50 of Set 13 | chokwe
# Processing Record 1 of Set 14 | buraydah
# Processing Record 2 of Set 14 | praia da vitoria
# Processing Record 3 of Set 14 | amahai
# Processing Record 4 of Set 14 | huangnihe
# Processing Record 5 of Set 14 | garoua boulai
# Processing Record 6 of Set 14 | baculin
# Processing Record 7 of Set 14 | skelleftea
# Processing Record 8 of Set 14 | nanortalik
# Processing Record 9 of Set 14 | chandur bazar
# Processing Record 10 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 14 | cedar rapids
# Processing Record 12 of Set 14 | grand gaube
# Processing Record 13 of Set 14 | hofn
# Processing Record 14 of Set 14 | point fortin
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | dandong
# Processing Record 17 of Set 14 | burnie
# Processing Record 18 of Set 14 | fairbanks
# Processing Record 19 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 14 | poya
# Processing Record 21 of Set 14 | harper
# Processing Record 22 of Set 14 | qarchi gak
# Processing Record 23 of Set 14 | hearst
# Processing Record 24 of Set 14 | misratah
# Processing Record 25 of Set 14 | vila
# Processing Record 26 of Set 14 | hami
# Processing Record 27 of Set 14 | nokaneng
# Processing Record 28 of Set 14 | concordia
# Processing Record 29 of Set 14 | nador
# Processing Record 30 of Set 14 | pointe michel
# Processing Record 31 of Set 14 | zyryanka
# Processing Record 32 of Set 14 | plover
# Processing Record 33 of Set 14 | maniitsoq
# Processing Record 34 of Set 14 | heyang
# Processing Record 35 of Set 14 | shelton
# Processing Record 36 of Set 14 | pierre
# Processing Record 37 of Set 14 | fasa
# Processing Record 38 of Set 14 | peoria
# Processing Record 39 of Set 14 | whyalla
# Processing Record 40 of Set 14 | onalaska
# Processing Record 41 of Set 14 | bima
# Processing Record 42 of Set 14 | labuhan
# Processing Record 43 of Set 14 | abong mbang
# Processing Record 44 of Set 14 | hay river
# Processing Record 45 of Set 14 | katangli
# Processing Record 46 of Set 14 | casablanca
# Processing Record 47 of Set 14 | kuusamo
# Processing Record 48 of Set 14 | araouane
# Processing Record 49 of Set 14 | makakilo city
# Processing Record 50 of Set 14 | rafaela
# Processing Record 1 of Set 15 | humaita
# Processing Record 2 of Set 15 | orlik
# Processing Record 3 of Set 15 | batagay-alyta
# Processing Record 4 of Set 15 | kholm
# Processing Record 5 of Set 15 | mantua
# Processing Record 6 of Set 15 | nova olimpia
# Processing Record 7 of Set 15 | muravlenko
# Processing Record 8 of Set 15 | fukagawa
# Processing Record 9 of Set 15 | ust-nera
# Processing Record 10 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 15 | sao geraldo do araguaia
# Processing Record 12 of Set 15 | viloco
# Processing Record 13 of Set 15 | killarney
# Processing Record 14 of Set 15 | male
# Processing Record 15 of Set 15 | bilibino
# Processing Record 16 of Set 15 | mancio lima
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | bhola
# Processing Record 19 of Set 15 | maiduguri
# Processing Record 20 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 15 | seminole
# Processing Record 22 of Set 15 | kyzyl-mazhalyk
# Processing Record 23 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 15 | plettenberg bay
# Processing Record 25 of Set 15 | labe
# Processing Record 26 of Set 15 | quesnel
# Processing Record 27 of Set 15 | terrace
# Processing Record 28 of Set 15 | zabid
# Processing Record 29 of Set 15 | northam
# Processing Record 30 of Set 15 | sibolga
# Processing Record 31 of Set 15 | belaya gora
# Processing Record 32 of Set 15 | koundara
# Processing Record 33 of Set 15 | valdivia
# Processing Record 34 of Set 15 | tarrafal
# Processing Record 35 of Set 15 | zarautz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Busselton -33.65  115.33     57.99        76           0        5.99
# 1       Ushuaia -54.80  -68.30     46.40        58          75       25.28
# 2       Rikitea -23.12 -134.97     74.50        68          29       11.72
# 3          Hilo  19.73 -155.09     84.20        58          40       10.29
# 4  Punta Arenas -53.15  -70.92     53.60        40          75       16.11
# 5        Hobart -42.88  147.33     57.00        54          75       12.75
# 6       Winslow  35.02 -110.70     73.40        18           1        5.55
# 7        Castro -24.79  -50.01     58.91        58           0        2.01
# 8        Riyadh  24.69   46.72     62.60        39           0        2.24
# 9    Sao Filipe  14.90  -24.50     76.95        76          10        5.50
#
#   Country                 Date Current Description
# 0      AU  2020-11-05 22:23:16           clear sky
# 1      AR  2020-11-05 22:21:01       broken clouds
# 2      PF  2020-11-05 22:23:13    scattered clouds
# 3      US  2020-11-05 22:22:06    scattered clouds
# 4      CL  2020-11-05 22:23:14       broken clouds
# 5      AU  2020-11-05 22:18:39       broken clouds
# 6      US  2020-11-05 22:27:12           clear sky
# 7      BR  2020-11-05 22:19:56           clear sky
# 8      SA  2020-11-05 22:25:53           clear sky
# 9      CV  2020-11-05 22:22:06           clear sky

# %%
new_city_data = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
new_city_data
# Out:
# ['City',
#  'Country',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Current Description']

# %%
city_data_df = city_data_df[new_city_data]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.65  115.33     57.99        76           0
# 1       Ushuaia      AR -54.80  -68.30     46.40        58          75
# 2       Rikitea      PF -23.12 -134.97     74.50        68          29
# 3          Hilo      US  19.73 -155.09     84.20        58          40
# 4  Punta Arenas      CL -53.15  -70.92     53.60        40          75
# 5        Hobart      AU -42.88  147.33     57.00        54          75
# 6       Winslow      US  35.02 -110.70     73.40        18           1
# 7        Castro      BR -24.79  -50.01     58.91        58           0
# 8        Riyadh      SA  24.69   46.72     62.60        39           0
# 9    Sao Filipe      CV  14.90  -24.50     76.95        76          10
#
#    Wind Speed Current Description
# 0        5.99           clear sky
# 1       25.28       broken clouds
# 2       11.72    scattered clouds
# 3       10.29    scattered clouds
# 4       16.11       broken clouds
# 5       12.75       broken clouds
# 6        5.55           clear sky
# 7        2.01           clear sky
# 8        2.24           clear sky
# 9        5.50           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
